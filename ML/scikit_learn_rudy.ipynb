# %%
from pycaret.nlp import *
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
import spacy
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# c:\Users\Apprenant\Desktop\Dev IA\Emotion_app\ML\scikit_learn_rudy.ipynb Cell 1' in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Apprenant/Desktop/Dev%20IA/Emotion_app/ML/scikit_learn_rudy.ipynb#ch0000000?line=2'>3</a> from sklearn.feature_extraction.text import CountVectorizer
#       <a href='vscode-notebook-cell:/c%3A/Users/Apprenant/Desktop/Dev%20IA/Emotion_app/ML/scikit_learn_rudy.ipynb#ch0000000?line=3'>4</a> import spacy
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Apprenant/Desktop/Dev%20IA/Emotion_app/ML/scikit_learn_rudy.ipynb#ch0000000?line=4'>5</a> spacy.load('en_core_web_sm')
#
# File ~\anaconda3\envs\pycaret0\lib\site-packages\spacy\__init__.py:30, in load(name, **overrides)
# ...

# %%
dfe = pd.read_csv("../Data/Data_cleaned/emotion_cleaned_rudy.csv")[["target", "clean_text"]].dropna()

# %%
vectorizer = CountVectorizer()
vectorizer.fit(dfe["clean_text"])
# Out:
# CountVectorizer()

# %%
# data = vectorizer.transform(dfe["clean_text"])
# df = pd.DataFrame(data)
# df["target"] = dfe.target

# %%
s = setup(dfe, target="target")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~\anaconda3\envs\pycaret0\lib\site-packages\pycaret\nlp.py:313, in setup(data, target, custom_stopwords, html, session_id, log_experiment, experiment_name, log_plots, log_data, verbose)
#     <a href='file:///c%3A/Users/Apprenant/anaconda3/envs/pycaret0/lib/site-packages/pycaret/nlp.py?line=310'>311</a>     import spacy
# --> <a href='file:///c%3A/Users/Apprenant/anaconda3/envs/pycaret0/lib/site-packages/pycaret/nlp.py?line=312'>313</a>     sp = spacy.load("en_core_web_sm", disable=["parser", "ner"])
#     <a href='file:///c%3A/Users/Apprenant/anaconda3/envs/pycaret0/lib/site-packages/pycaret/nlp.py?line=313'>314</a> except:
#
# File ~\anaconda3\envs\pycaret0\lib\site-packages\spacy\__init__.py:30, in load(name, **overrides)
# ...
